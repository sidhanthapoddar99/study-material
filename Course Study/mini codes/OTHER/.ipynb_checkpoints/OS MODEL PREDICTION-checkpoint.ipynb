# %%
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split as tts

# %%
dataset = pd.read_csv("C:\\Users\\Sid\\Desktop\\os\\a.csv")

# %%
xtrain  = dataset.drop(['TQ'] ,1)
ytrain = dataset[['TQ']]

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2481 entries, 0 to 2480
# Data columns (total 5 columns):
# Unnamed: 0    2481 non-null int64
# Unnamed: 1    2481 non-null int64
# Unnamed: 2    2481 non-null int64
# Unnamed: 3    2481 non-null int64
# Unnamed: 4    2481 non-null int64
# dtypes: int64(5)
# memory usage: 97.0 KB

# %%
ytrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2481 entries, 0 to 2480
# Data columns (total 1 columns):
# TQ    2481 non-null int64
# dtypes: int64(1)
# memory usage: 19.5 KB

# %%
x_train, x_test, y_train, y_test = tts(xtrain, ytrain, test_size = 0.2, random_state = 42)

# %%
rf = RFR()

# %%
rf.fit(x_train, y_train)
# Out:
# C:\Users\Sid\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Sid\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
x_test
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 254           22          37           0          72          84
# 621          133          76          35         213           0
# 1730          42           0           0           0          97
# 1792          56         140           0           0          52
# 819           76          19           0         157           0
# 1583          19         139          50           0           0
# 879           98          41           1         179           0
# 1414           8          96         107           0           0
# 2164         144         164           0          95           0
# 497          150          93           0          18         230
# 1089           0           0          86         166          29
# 432          122          65           0           0         202
# 1929          75         159          19           0          71
# ...

# %%
#y_pred = rf.predict(x_test)
y_pred = rf.predict([[10,1,1159,5,111]])

# %%
y_pred.round()
# Out:
# array([103.])

# %%
x_train.iloc[0]
# Out:
# Unnamed: 0     0
# Unnamed: 1     5
# Unnamed: 2    10
# Unnamed: 3    40
# Unnamed: 4    52
# Name: 212, dtype: int64

# %%
from xgboost.sklearn import XGBRegressor  
xgbreg = XGBRegressor()

# %%
y_test1 = xgbreg.predict(x_train[0:1])
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-112-e1cf98105fd9> in <module>()
# ----> 1 y_test1 = xgbreg.predict(x_train[0:1])
#
# ~\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit)
#     343         if ntree_limit is None:
#     344             ntree_limit = getattr(self, "best_ntree_limit", 0)
# --> 345         return self.get_booster().predict(test_dmatrix,
#     346                                           output_margin=output_margin,
#     347                                           ntree_limit=ntree_limit)
#
# ~\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\xgboost\sklearn.py in get_booster(self)
#     177         """
#     178         if self._Booster is None:
# --> 179             raise XGBoostError('need to call fit or load_model beforehand')
# ...

# %%
y_test1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-2e3885a6de38> in <module>()
# ----> 1 y_test1
#
# NameError: name 'y_test1' is not defined

# %%
df = pd.DataFrame([10, 1, 1159, 2, 1])

# %%
df_test = pd.DataFrame(np.array(df).transpose())

# %%
x_test.iloc[-1] = [10, 1, 1159, 2, 1]
# Out:
# C:\Users\Sid\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Sid\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x_test
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 254           22          37           0          72          84
# 621          133          76          35         213           0
# 1730          42           0           0           0          97
# 1792          56         140           0           0          52
# 819           76          19           0         157           0
# 1583          19         139          50           0           0
# 879           98          41           1         179           0
# 1414           8          96         107           0           0
# 2164         144         164           0          95           0
# 497          150          93           0          18         230
# 1089           0           0          86         166          29
# 432          122          65           0           0         202
# 1929          75         159          19           0          71
# ...

# %%
y_test_1 = rf.predict(np.array(x_test.iloc[-1]).reshape(1,-1))

# %%
y_test
# Out:
#        TQ
# 254    72
# 621   133
# 1730   42
# 1792   56
# 819    19
# 1583   19
# 879     1
# 1414   96
# 2164  164
# 497    18
# 1089   29
# 432   122
# 1929   19
# 1576   26
# 798    97
# 56     45
# 986    49
# 178    19
# 2044  205
# 1266    1
# 1761   11
# 1508    9
# 1273   90
# 2349  148
# 1808   40
# 808    87
# 1983   22
# 1394   20
# 1071   47
# 43     31
# ...   ...
# 1110    8
# 1018   17
# 84      4
# 1632   39
# 2031  218
# 1655   16
# 1836   12
# 2195  133
# 461    93
# 109     6
# 2082   79
# 354    69
# 1014   21
# 873     7
# 695    18
# 554    38
# 290    35
# 1087   31
# 1304   59
# 416     6
# 472    25
# 923    12
# 2019  230
# 402    20
# 1805   43
# 810    28
# 1813   35
# 2032  217
# 2400   28
# 1488   23
#
# [497 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
y_pred.round()
# Out:
# array([ 72., 133.,  42.,  55.,  20.,  20.,  11.,  51., 164.,  10.,  29.,
#        122.,  19.,  25.,  97.,  45.,  47.,  19., 194.,   2.,  10.,   8.,
#         90., 147.,  39.,  87.,  22.,  19.,  46.,  31., 130.,   9.,  23.,
#         28.,  32., 113., 124.,  27.,   4., 146.,  17.,  17.,  47.,  18.,
#          7.,  12.,   5.,  11., 211.,  40.,  44.,  56., 204.,  89.,  13.,
#         19.,   6.,   2.,  46.,  11., 202.,  10.,  12.,  69.,  35.,  12.,
#        125.,   8.,   4.,   6.,  42.,  79., 104.,  47.,  23.,  22.,  24.,
#         49.,  22.,  11.,   7., 146.,  83., 110.,  48.,  18., 158.,  62.,
#         14.,  24., 162.,  13.,  80.,   7.,   2.,  18.,  10.,   8., 223.,
#          6.,  16.,  16.,  15., 110., 120.,  19.,  13.,  40.,  62.,  27.,
#          2.,  70., 123.,  89.,   9.,  42., 160.,  40.,   5.,  49.,  10.,
#         97., 212.,   9.,  84.,   9.,  44.,   7.,  67.,  92.,   1.,   9.,
#        165.,  18., 100.,   3., 130.,  21.,   6.,  57.,  42.,  33.,  46.,
# ...

# %%
acc = 0
for i in range(len(y_test)):
    if np.array(y_test)[i] == y_pred.round()[i]:
        acc = acc+1
    elif abs(np.array(y_test)[i]-y_pred.round()[i]) in range(1,5):
        acc = acc+1
acc
# Out:
# 457

# %%
len(y_test)
# Out:
# 497

# %%
acc/497
# Out:
# 0.9195171026156942
