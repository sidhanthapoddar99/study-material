# %% [markdown]
# # DIGITAL ASSIGNMENT
# ## KMEANS CLUSTERING
# ### NAME SIDHANTHA PODDAR
# ### ROLLNO 17BCE2044

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('East+Midlands.csv')
print(data.shape)
data.head()
# Out:
# (23677, 26)
#    Year    CP Estimation_method  \
# 0  2000  6004           Counted
# 1  2000  6005           Counted
# 2  2000  6006           Counted
# 3  2000  6043           Counted
# 4  2000  6082         Estimated
#
#                           Estimation_method_detailed         Region  \
# 0                                       Manual count  East Midlands
# 1                                       Manual count  East Midlands
# 2                                       Manual count  East Midlands
# 3                                       Manual count  East Midlands
# 4  Estimated using previous year's AADF on this link  East Midlands
#
#      LocalAuthority Road RoadCategory  Easting  Northing  ... BusesCoaches  \
# 0  Northamptonshire   M1           TM   458354    270523  ...       289.58
# 1    Leicestershire   M1           TM   447940    312400  ...       780.42
# 2        Derbyshire   M1           TM   446420    355300  ...       157.40
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.rcParams['figure.figsize'] = (10,8)
X=data
# Creating a sample dataset with 4 clusters
X,Y = make_blobs(n_samples=23677, n_features=25, centers=9)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2],X[:,3],s=20)

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
C
# Out:
# array([[-2.11662986e+00, -8.68115769e+00, -4.31173051e+00,
#          6.67963995e+00, -4.32489287e+00,  4.08539729e+00,
#         -1.00496743e+00, -4.04598438e+00, -4.66583377e+00,
#         -5.54089195e-01,  4.79366686e+00,  2.45084516e+00,
#         -6.33107822e-01,  6.47012396e+00, -2.85497840e+00,
#          7.48780978e+00, -2.89950329e+00, -4.48614949e+00,
#          1.60276744e+00, -7.33902372e+00,  2.45827226e-01,
#         -1.06700274e+00, -6.11940909e-01,  2.46288221e+00,
#         -4.09258300e+00],
#        [ 1.52972804e-01,  7.76156845e+00, -1.62240869e+00,
#         -2.84969310e-01, -2.16645399e+00,  3.53919329e-01,
#          8.14015904e+00, -3.52788920e-03,  8.21409183e-01,
#          6.39890521e+00, -5.28296073e+00,  1.11244317e+00,
#          9.54035033e-01,  3.09461297e+00,  2.98482207e+00,
#          3.90281709e-01,  4.55691726e+00,  4.75728727e+00,
#          1.19142329e+00, -3.71171613e+00, -4.48806628e-01,
# ...

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2],X[:,3] ,c=Y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2],X[:,3], marker='*', c='#050505', s=1000)
# Out:
# C:\Users\Sid\AppData\Local\conda\conda\envs\image\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:728: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# C:\Users\Sid\AppData\Local\conda\conda\envs\image\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:730: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':
